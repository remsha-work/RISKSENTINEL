# %% [markdown]
# <a href="https://colab.research.google.com/github/remsha-work/RISKSENTINEL/blob/main/analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
